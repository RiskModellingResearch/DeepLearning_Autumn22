# %%
# !git clone https://github.com/RiskModellingResearch/DeepLearning_Autumn22.git
# Out:
# Cloning into 'DeepLearning_Autumn22'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 71 (delta 20), reused 62 (delta 11), pack-reused 0
# Unpacking objects: 100% (71/71), done.

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.7.2-py3-none-any.whl (397 kB)
#      |████████████████████████████████| 397 kB 4.3 MB/s
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.10.0+cu111)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.7)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.7.2

# %%
import numpy as np
import pandas as pd
import pickle

import torch
print(torch.__version__)

import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from torchmetrics import Accuracy
from torch.utils.data import Dataset, DataLoader
# Out:
# 1.10.0+cu111

# %%
class CustomDataset(Dataset):

    def __init__(self, dataset_path):
        with open(dataset_path, 'rb') as f:
            data, self.nrof_emb_categories, self.unique_categories = pickle.load(f)

        self.embedding_columns = ['workclass_cat', 'education_cat', 'marital-status_cat', 'occupation_cat',
                                  'relationship_cat', 'race_cat', 'sex_cat', 'native-country_cat']
        self.nrof_emb_categories = {key + '_cat': val for key, val in self.nrof_emb_categories.items()}
        self.numeric_columns = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

        self.columns = self.embedding_columns + self.numeric_columns
        self.X = data[self.columns].reset_index(drop=True)
        self.y = np.asarray([0 if el == '<50k' else 1 for el in data['salary'].values], dtype=np.int32)
        return

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        row = self.X.take([idx], axis=0)
        row = {col: torch.tensor(row[col].values, dtype=torch.float32) for i, col in enumerate(self.columns)}
        return row, np.float32(self.y[idx])

# %%
class DenseFeatureLayer(nn.Module):

    def __init__(self, nrof_cat, emb_dim, emb_columns, numeric_columns):
        super(DenseFeatureLayer, self).__init__()

        self.emb_columns = emb_columns
        self.numeric_columns = numeric_columns
        self.numeric_feature_bn = torch.nn.BatchNorm1d(len(numeric_columns))

        input_size = len(emb_columns) + len(numeric_columns)
        self.first_feature_bn = torch.nn.BatchNorm1d(input_size)
        self.second_feature_bn = torch.nn.BatchNorm1d(input_size)

        # first order feature interactions
        self.first_order_embd = nn.ModuleDict()
        for i, col in enumerate(self.emb_columns):
            self.first_order_embd[col] = torch.nn.Embedding(nrof_cat[col], 1)
        self.first_order_scalar = nn.ParameterDict({})
        for i, col in enumerate(numeric_columns):
            self.first_order_scalar[col] = nn.Parameter(torch.nn.init.xavier_uniform_(torch.empty(1,1)))

        # second order feature interactions
        self.second_order_embd = nn.ModuleDict({})
        for i, col in enumerate(self.emb_columns):
            self.second_order_embd[col] = torch.nn.Embedding(nrof_cat[col], emb_dim)
        self.second_order_scalar = nn.ParameterDict({})
        for i, col in enumerate(numeric_columns):
            self.second_order_scalar[col] = nn.Parameter(torch.nn.init.xavier_uniform_(torch.empty(emb_dim, 1)))
        return

    def forward(self, input_data):
        numeric_features = torch.stack([input_data[col] for col in self.numeric_columns], dim=1)
        numeric_features = self.numeric_feature_bn(numeric_features)

        # first order feature interactions
        # categorical_columns
        first_order_embd_output = None
        for i, col in enumerate(self.emb_columns):
            if first_order_embd_output is None:
                first_order_embd_output = self.first_order_embd[col](
                    torch.tensor(input_data[self.emb_columns[i]], dtype=torch.int64))
            else:
                first_order_embd_output = torch.cat(
                    [first_order_embd_output, self.first_order_embd[col](
                        torch.tensor(input_data[self.emb_columns[i]], dtype=torch.int64))], dim=1)

        # numeric_columns
        first_order_embd_output = torch.squeeze(first_order_embd_output, dim=2)
        for i, col in enumerate(self.numeric_columns):
            if first_order_embd_output is None:
                first_order_embd_output = torch.mul(numeric_features[i], self.first_order_scalar[col])
            else:
                first_order_embd_output = torch.cat(
                    [first_order_embd_output, torch.mul(numeric_features[:, i], self.first_order_scalar[col])], dim=1)
                
        # second order feature interactions
        # categorical_columns
        second_order_embd_output = None
        for i, col in enumerate(self.emb_columns):
            if second_order_embd_output is None:
                second_order_embd_output = self.second_order_embd[col](
                    torch.tensor(input_data[self.emb_columns[i]], dtype=torch.int64))
            else:
                second_order_embd_output = torch.cat(
                    [second_order_embd_output, self.second_order_embd[col](
                        torch.tensor(input_data[self.emb_columns[i]], dtype=torch.int64))], dim=1)

        # numeric_columns
        for i, col in enumerate(self.numeric_columns):
            if second_order_embd_output is None:
                second_order_embd_output = torch.mul(numeric_features[i], self.second_order_scalar[col])
            else:
                second_order_embd_output = torch.cat(
                    [second_order_embd_output, torch.unsqueeze(torch.mul(
                        numeric_features[:, i], torch.squeeze(
                            torch.stack([self.second_order_scalar[col]] * len(numeric_features)), 2)), 1)], dim=1)

        first_order_embd_output = self.first_feature_bn(first_order_embd_output)
        second_order_embd_output = self.second_feature_bn(second_order_embd_output)
        return first_order_embd_output, second_order_embd_output

# %%
class FMLayer(nn.Module):

    def __init__(self, ):
        super(FMLayer, self).__init__()
        return

    def forward(self, first_order_embd, second_order_embd):
        # sum_square part
        summed_features_embd = torch.sum(second_order_embd, dim=1)
        summed_features_embd_square = torch.square(summed_features_embd)

        # square_sum part
        squared_features_embd = torch.square(second_order_embd)
        squared_sum_features_embd = torch.sum(squared_features_embd, dim=1)

        # second order
        second_order = 0.5 * torch.sub(summed_features_embd_square, squared_sum_features_embd)
        return first_order_embd, second_order

# %%
class MLPLayer(nn.Module):

    def __init__(self, input_size, nrof_layers, nrof_neurons, output_size):
        super(MLPLayer, self).__init__()
        all_input_sizes = [input_size]
        [all_input_sizes.append(nrof_neurons) for i in range(nrof_layers - 1)]
        list_layers = []
        [list_layers.extend([torch.nn.Linear(all_input_sizes[i], nrof_neurons),
                             torch.nn.BatchNorm1d(nrof_neurons),
                             torch.nn.ReLU()]) for i in range(nrof_layers - 1)]
        self.deep_block = torch.nn.Sequential(*list_layers)
        self.output_layer = torch.nn.Linear(nrof_neurons, output_size)

    def init_weights(self, m):
        if type(m) == nn.Linear:
            torch.nn.init.xavier_uniform(m.weight)
            # m.bias.data.fill_(0.001)

    def forward(self, input_data):
        output = self.deep_block(input_data)
        output = self.output_layer(output)
        return output

# %%
class DeepFMNet(nn.Module):

    def __init__(self, nrof_cat, emb_dim, emb_columns, numeric_columns,
                 nrof_layers, nrof_neurons, output_size, nrof_out_classes):
        super(DeepFMNet, self).__init__()
        self.emb_dim = emb_dim
        self.emb_columns = emb_columns
        self.numeric_columns = numeric_columns

        self.features_embd = DenseFeatureLayer(nrof_cat, emb_dim, emb_columns, numeric_columns)
        self.FM = FMLayer()

        input_size = (len(emb_columns) + len(numeric_columns)) * emb_dim
        self.MLP = MLPLayer(input_size, nrof_layers, nrof_neurons, output_size)

        input_size = len(emb_columns) + len(numeric_columns) + emb_dim + output_size
        self.dense_layer = nn.Linear(input_size, nrof_out_classes)

    def forward(self, input_data):
        first_order_embd, second_order_embd = self.features_embd(input_data)
        FM_first_order, FM_second_order = self.FM(first_order_embd, second_order_embd)

        second_order_embd = torch.reshape(second_order_embd, 
                                          [-1, (len(self.emb_columns) + len(self.numeric_columns)) * self.emb_dim])
        Deep = self.MLP(second_order_embd)

        concat_output = torch.cat([FM_first_order, FM_second_order, Deep], dim=1)
        output = self.dense_layer(concat_output)
        output = torch.squeeze(output, 1)
        return output

# %%
EPOCHS = 500
EMBEDDING_SIZE = 5
BATCH_SIZE = 512
NROF_LAYERS = 3
NROF_NEURONS = 50
DEEP_OUTPUT_SIZE = 50
NROF_OUT_CLASSES = 1
LEARNING_RATE = 3e-4
TRAIN_PATH = 'DeepLearning_Autumn22/week_05/data/train_adult.pickle'
VALID_PATH = 'DeepLearning_Autumn22/week_05/data/valid_adult.pickle'

# %%
class DeepFM:
    def __init__(self):
        self.train_dataset = CustomDataset(TRAIN_PATH)
        self.train_loader = DataLoader(dataset=self.train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        self.build_model()
        self.log_params()
        self.train_writer = SummaryWriter('./logs/train')
        self.valid_writer = SummaryWriter('./logs/valid')
        return

    def build_model(self):
        self.network = DeepFMNet(nrof_cat=self.train_dataset.nrof_emb_categories, 
                                 emb_dim=EMBEDDING_SIZE,
                                 emb_columns=self.train_dataset.embedding_columns,
                                 numeric_columns=self.train_dataset.numeric_columns,
                                 nrof_layers=NROF_LAYERS, nrof_neurons=NROF_NEURONS,
                                 output_size=DEEP_OUTPUT_SIZE,
                                 nrof_out_classes=NROF_OUT_CLASSES)

        self.loss = torch.nn.BCEWithLogitsLoss()
        self.accuracy = Accuracy()
        self.optimizer = optim.Adam(self.network.parameters(), lr=LEARNING_RATE)
        return

    def log_params(self):
        return

    def load_model(self, restore_path=''):
        if restore_path == '':
            self.step = 0
        else:
            pass
        return

    def run_train(self):
        print('Run train ...')
        self.load_model()
        for epoch in range(EPOCHS):
            self.network.train()
            
            for features, label in self.train_loader:
                # Reset gradients
                self.optimizer.zero_grad()
                output = self.network(features)

                # Calculate error and backpropagate
                loss = self.loss(output, label)
                output = torch.sigmoid(output)
                loss.backward()
                acc = self.accuracy(output, torch.tensor(label, dtype=torch.int64)).item()

                # Update weights with gradients
                self.optimizer.step()
                self.train_writer.add_scalar('CrossEntropyLoss', loss, self.step)
                self.train_writer.add_scalar('Accuracy', acc, self.step)
                self.step += 1

                if self.step % 50 == 0:
                    print('EPOCH %d STEP %d : train_loss: %f train_acc: %f' %(epoch, self.step, loss.item(), acc))

            # self.train_writer.add_histogram('hidden_layer', self.network.linear1.weight.data, self.step)
            # Run validation
            #TODO
        return

# %%
deep_fm = DeepFM()
deep_fm.run_train()
# Out:
# Run train ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# EPOCH 0 STEP 50 : train_loss: nan train_acc: 0.748047
# EPOCH 1 STEP 100 : train_loss: nan train_acc: 0.765625
# EPOCH 2 STEP 150 : train_loss: nan train_acc: 0.783203
# EPOCH 3 STEP 200 : train_loss: nan train_acc: 0.759766
# EPOCH 4 STEP 250 : train_loss: nan train_acc: 0.761719
# EPOCH 5 STEP 300 : train_loss: nan train_acc: 0.742188
# EPOCH 6 STEP 350 : train_loss: nan train_acc: 0.753906
# EPOCH 7 STEP 400 : train_loss: nan train_acc: 0.744141
# EPOCH 8 STEP 450 : train_loss: nan train_acc: 0.720703
# EPOCH 9 STEP 500 : train_loss: nan train_acc: 0.744141
# EPOCH 10 STEP 550 : train_loss: nan train_acc: 0.748047
# EPOCH 11 STEP 600 : train_loss: nan train_acc: 0.746094
# EPOCH 12 STEP 650 : train_loss: nan train_acc: 0.755859
# EPOCH 13 STEP 700 : train_loss: nan train_acc: 0.724609
# EPOCH 14 STEP 750 : train_loss: nan train_acc: 0.744141
# EPOCH 15 STEP 800 : train_loss: nan train_acc: 0.710938
# EPOCH 16 STEP 850 : train_loss: nan train_acc: 0.718750
# EPOCH 17 STEP 900 : train_loss: nan train_acc: 0.750000
# EPOCH 18 STEP 950 : train_loss: nan train_acc: 0.738281
# EPOCH 19 STEP 1000 : train_loss: nan train_acc: 0.746094
# EPOCH 20 STEP 1050 : train_loss: nan train_acc: 0.763672
# EPOCH 21 STEP 1100 : train_loss: nan train_acc: 0.775391
# EPOCH 22 STEP 1150 : train_loss: nan train_acc: 0.710938
# EPOCH 23 STEP 1200 : train_loss: nan train_acc: 0.763672
# EPOCH 24 STEP 1250 : train_loss: nan train_acc: 0.789062
# EPOCH 25 STEP 1300 : train_loss: nan train_acc: 0.753906
# EPOCH 26 STEP 1350 : train_loss: nan train_acc: 0.730469
# EPOCH 27 STEP 1400 : train_loss: nan train_acc: 0.734375
# EPOCH 28 STEP 1450 : train_loss: nan train_acc: 0.767578
# EPOCH 29 STEP 1500 : train_loss: nan train_acc: 0.753906
# EPOCH 30 STEP 1550 : train_loss: nan train_acc: 0.761719
# EPOCH 31 STEP 1600 : train_loss: nan train_acc: 0.728516
# EPOCH 32 STEP 1650 : train_loss: nan train_acc: 0.798828
# EPOCH 33 STEP 1700 : train_loss: nan train_acc: 0.744141
# EPOCH 34 STEP 1750 : train_loss: nan train_acc: 0.744141
# EPOCH 35 STEP 1800 : train_loss: nan train_acc: 0.769531
# EPOCH 36 STEP 1850 : train_loss: nan train_acc: 0.757812
# EPOCH 37 STEP 1900 : train_loss: nan train_acc: 0.769531
# EPOCH 38 STEP 1950 : train_loss: nan train_acc: 0.763672
# EPOCH 39 STEP 2000 : train_loss: nan train_acc: 0.789062
# EPOCH 40 STEP 2050 : train_loss: nan train_acc: 0.789062
# EPOCH 41 STEP 2100 : train_loss: nan train_acc: 0.761719
# EPOCH 42 STEP 2150 : train_loss: nan train_acc: 0.775391
# EPOCH 43 STEP 2200 : train_loss: nan train_acc: 0.761719
# EPOCH 44 STEP 2250 : train_loss: nan train_acc: 0.736328
# EPOCH 45 STEP 2300 : train_loss: nan train_acc: 0.763672
# EPOCH 46 STEP 2350 : train_loss: nan train_acc: 0.761719
# EPOCH 47 STEP 2400 : train_loss: nan train_acc: 0.746094
# EPOCH 48 STEP 2450 : train_loss: nan train_acc: 0.777344
# EPOCH 49 STEP 2500 : train_loss: nan train_acc: 0.773438
# EPOCH 49 STEP 2550 : train_loss: nan train_acc: 0.776786
# EPOCH 50 STEP 2600 : train_loss: nan train_acc: 0.794922
# EPOCH 51 STEP 2650 : train_loss: nan train_acc: 0.734375
# EPOCH 52 STEP 2700 : train_loss: nan train_acc: 0.767578
# EPOCH 53 STEP 2750 : train_loss: nan train_acc: 0.785156
# EPOCH 54 STEP 2800 : train_loss: nan train_acc: 0.767578
# EPOCH 55 STEP 2850 : train_loss: nan train_acc: 0.763672
# EPOCH 56 STEP 2900 : train_loss: nan train_acc: 0.730469
# EPOCH 57 STEP 2950 : train_loss: nan train_acc: 0.769531
# EPOCH 58 STEP 3000 : train_loss: nan train_acc: 0.728516
# EPOCH 59 STEP 3050 : train_loss: nan train_acc: 0.783203
# EPOCH 60 STEP 3100 : train_loss: nan train_acc: 0.761719
# EPOCH 61 STEP 3150 : train_loss: nan train_acc: 0.800781
# EPOCH 62 STEP 3200 : train_loss: nan train_acc: 0.742188
# EPOCH 63 STEP 3250 : train_loss: nan train_acc: 0.787109
# EPOCH 64 STEP 3300 : train_loss: nan train_acc: 0.769531
# EPOCH 65 STEP 3350 : train_loss: nan train_acc: 0.738281
# EPOCH 66 STEP 3400 : train_loss: nan train_acc: 0.753906
# EPOCH 67 STEP 3450 : train_loss: nan train_acc: 0.765625
# EPOCH 68 STEP 3500 : train_loss: nan train_acc: 0.789062
# EPOCH 69 STEP 3550 : train_loss: nan train_acc: 0.763672
# EPOCH 70 STEP 3600 : train_loss: nan train_acc: 0.755859
# EPOCH 71 STEP 3650 : train_loss: nan train_acc: 0.763672
# EPOCH 72 STEP 3700 : train_loss: nan train_acc: 0.750000
# EPOCH 73 STEP 3750 : train_loss: nan train_acc: 0.755859
# EPOCH 74 STEP 3800 : train_loss: nan train_acc: 0.775391
# EPOCH 75 STEP 3850 : train_loss: nan train_acc: 0.781250
# EPOCH 76 STEP 3900 : train_loss: nan train_acc: 0.757812
# EPOCH 77 STEP 3950 : train_loss: nan train_acc: 0.751953
# EPOCH 78 STEP 4000 : train_loss: nan train_acc: 0.769531
# EPOCH 79 STEP 4050 : train_loss: nan train_acc: 0.730469
# EPOCH 80 STEP 4100 : train_loss: nan train_acc: 0.775391
# EPOCH 81 STEP 4150 : train_loss: nan train_acc: 0.757812
# EPOCH 82 STEP 4200 : train_loss: nan train_acc: 0.751953
# EPOCH 83 STEP 4250 : train_loss: nan train_acc: 0.728516
# EPOCH 84 STEP 4300 : train_loss: nan train_acc: 0.757812
# EPOCH 85 STEP 4350 : train_loss: nan train_acc: 0.785156
# EPOCH 86 STEP 4400 : train_loss: nan train_acc: 0.781250
# EPOCH 87 STEP 4450 : train_loss: nan train_acc: 0.734375
# EPOCH 88 STEP 4500 : train_loss: nan train_acc: 0.753906
# EPOCH 89 STEP 4550 : train_loss: nan train_acc: 0.738281
# EPOCH 90 STEP 4600 : train_loss: nan train_acc: 0.736328
# EPOCH 91 STEP 4650 : train_loss: nan train_acc: 0.767578
# EPOCH 92 STEP 4700 : train_loss: nan train_acc: 0.740234
# EPOCH 93 STEP 4750 : train_loss: nan train_acc: 0.753906
# EPOCH 94 STEP 4800 : train_loss: nan train_acc: 0.746094
# EPOCH 95 STEP 4850 : train_loss: nan train_acc: 0.763672
# EPOCH 96 STEP 4900 : train_loss: nan train_acc: 0.771484
# EPOCH 97 STEP 4950 : train_loss: nan train_acc: 0.765625
# EPOCH 98 STEP 5000 : train_loss: nan train_acc: 0.759766
# EPOCH 99 STEP 5050 : train_loss: nan train_acc: 0.767578
# EPOCH 99 STEP 5100 : train_loss: nan train_acc: 0.796875
# EPOCH 100 STEP 5150 : train_loss: nan train_acc: 0.750000
# EPOCH 101 STEP 5200 : train_loss: nan train_acc: 0.757812
# EPOCH 102 STEP 5250 : train_loss: nan train_acc: 0.775391
# EPOCH 103 STEP 5300 : train_loss: nan train_acc: 0.771484
# EPOCH 104 STEP 5350 : train_loss: nan train_acc: 0.769531
# EPOCH 105 STEP 5400 : train_loss: nan train_acc: 0.748047
# EPOCH 106 STEP 5450 : train_loss: nan train_acc: 0.750000
# EPOCH 107 STEP 5500 : train_loss: nan train_acc: 0.759766
# EPOCH 108 STEP 5550 : train_loss: nan train_acc: 0.744141
# EPOCH 109 STEP 5600 : train_loss: nan train_acc: 0.744141
# EPOCH 110 STEP 5650 : train_loss: nan train_acc: 0.818359
# EPOCH 111 STEP 5700 : train_loss: nan train_acc: 0.781250
# EPOCH 112 STEP 5750 : train_loss: nan train_acc: 0.771484
# EPOCH 113 STEP 5800 : train_loss: nan train_acc: 0.753906
# EPOCH 114 STEP 5850 : train_loss: nan train_acc: 0.777344
# EPOCH 115 STEP 5900 : train_loss: nan train_acc: 0.787109
# EPOCH 116 STEP 5950 : train_loss: nan train_acc: 0.773438
# EPOCH 117 STEP 6000 : train_loss: nan train_acc: 0.740234
# EPOCH 118 STEP 6050 : train_loss: nan train_acc: 0.730469
# EPOCH 119 STEP 6100 : train_loss: nan train_acc: 0.753906
# EPOCH 120 STEP 6150 : train_loss: nan train_acc: 0.751953
# EPOCH 121 STEP 6200 : train_loss: nan train_acc: 0.740234
# EPOCH 122 STEP 6250 : train_loss: nan train_acc: 0.742188
# EPOCH 123 STEP 6300 : train_loss: nan train_acc: 0.783203
# EPOCH 124 STEP 6350 : train_loss: nan train_acc: 0.785156
# EPOCH 125 STEP 6400 : train_loss: nan train_acc: 0.771484
# EPOCH 126 STEP 6450 : train_loss: nan train_acc: 0.740234
# EPOCH 127 STEP 6500 : train_loss: nan train_acc: 0.757812
# EPOCH 128 STEP 6550 : train_loss: nan train_acc: 0.716797
# EPOCH 129 STEP 6600 : train_loss: nan train_acc: 0.724609
# EPOCH 130 STEP 6650 : train_loss: nan train_acc: 0.775391
# EPOCH 131 STEP 6700 : train_loss: nan train_acc: 0.779297
# EPOCH 132 STEP 6750 : train_loss: nan train_acc: 0.763672
# EPOCH 133 STEP 6800 : train_loss: nan train_acc: 0.734375
# EPOCH 134 STEP 6850 : train_loss: nan train_acc: 0.755859
# EPOCH 135 STEP 6900 : train_loss: nan train_acc: 0.785156
# EPOCH 136 STEP 6950 : train_loss: nan train_acc: 0.767578
# EPOCH 137 STEP 7000 : train_loss: nan train_acc: 0.726562
# EPOCH 138 STEP 7050 : train_loss: nan train_acc: 0.751953
# EPOCH 139 STEP 7100 : train_loss: nan train_acc: 0.779297
# EPOCH 140 STEP 7150 : train_loss: nan train_acc: 0.748047
# EPOCH 141 STEP 7200 : train_loss: nan train_acc: 0.802734
# EPOCH 142 STEP 7250 : train_loss: nan train_acc: 0.746094
# EPOCH 143 STEP 7300 : train_loss: nan train_acc: 0.748047
# EPOCH 144 STEP 7350 : train_loss: nan train_acc: 0.763672
# EPOCH 145 STEP 7400 : train_loss: nan train_acc: 0.751953
# EPOCH 146 STEP 7450 : train_loss: nan train_acc: 0.791016
# EPOCH 147 STEP 7500 : train_loss: nan train_acc: 0.751953
# EPOCH 148 STEP 7550 : train_loss: nan train_acc: 0.755859
# EPOCH 149 STEP 7600 : train_loss: nan train_acc: 0.769531
# EPOCH 149 STEP 7650 : train_loss: nan train_acc: 0.714286
# EPOCH 150 STEP 7700 : train_loss: nan train_acc: 0.771484
# EPOCH 151 STEP 7750 : train_loss: nan train_acc: 0.777344
# EPOCH 152 STEP 7800 : train_loss: nan train_acc: 0.779297
# EPOCH 153 STEP 7850 : train_loss: nan train_acc: 0.765625
# EPOCH 154 STEP 7900 : train_loss: nan train_acc: 0.734375
# EPOCH 155 STEP 7950 : train_loss: nan train_acc: 0.761719
# EPOCH 156 STEP 8000 : train_loss: nan train_acc: 0.720703
# EPOCH 157 STEP 8050 : train_loss: nan train_acc: 0.765625
# EPOCH 158 STEP 8100 : train_loss: nan train_acc: 0.765625
# EPOCH 159 STEP 8150 : train_loss: nan train_acc: 0.775391
# EPOCH 160 STEP 8200 : train_loss: nan train_acc: 0.746094
# EPOCH 161 STEP 8250 : train_loss: nan train_acc: 0.785156
# EPOCH 162 STEP 8300 : train_loss: nan train_acc: 0.751953
# EPOCH 163 STEP 8350 : train_loss: nan train_acc: 0.763672
# EPOCH 164 STEP 8400 : train_loss: nan train_acc: 0.750000
# EPOCH 165 STEP 8450 : train_loss: nan train_acc: 0.751953
# EPOCH 166 STEP 8500 : train_loss: nan train_acc: 0.767578
# EPOCH 167 STEP 8550 : train_loss: nan train_acc: 0.753906
# EPOCH 168 STEP 8600 : train_loss: nan train_acc: 0.746094
# EPOCH 169 STEP 8650 : train_loss: nan train_acc: 0.794922
# EPOCH 170 STEP 8700 : train_loss: nan train_acc: 0.769531
# EPOCH 171 STEP 8750 : train_loss: nan train_acc: 0.740234
# EPOCH 172 STEP 8800 : train_loss: nan train_acc: 0.781250
# EPOCH 173 STEP 8850 : train_loss: nan train_acc: 0.744141
# EPOCH 174 STEP 8900 : train_loss: nan train_acc: 0.740234
# EPOCH 175 STEP 8950 : train_loss: nan train_acc: 0.767578
# EPOCH 176 STEP 9000 : train_loss: nan train_acc: 0.769531
# EPOCH 177 STEP 9050 : train_loss: nan train_acc: 0.738281
# EPOCH 178 STEP 9100 : train_loss: nan train_acc: 0.773438
# EPOCH 179 STEP 9150 : train_loss: nan train_acc: 0.792969
# EPOCH 180 STEP 9200 : train_loss: nan train_acc: 0.779297
# EPOCH 181 STEP 9250 : train_loss: nan train_acc: 0.789062
# EPOCH 182 STEP 9300 : train_loss: nan train_acc: 0.732422
# EPOCH 183 STEP 9350 : train_loss: nan train_acc: 0.792969
# EPOCH 184 STEP 9400 : train_loss: nan train_acc: 0.759766
# EPOCH 185 STEP 9450 : train_loss: nan train_acc: 0.779297
# EPOCH 186 STEP 9500 : train_loss: nan train_acc: 0.757812
# EPOCH 187 STEP 9550 : train_loss: nan train_acc: 0.759766
# EPOCH 188 STEP 9600 : train_loss: nan train_acc: 0.767578
# EPOCH 189 STEP 9650 : train_loss: nan train_acc: 0.757812
# EPOCH 190 STEP 9700 : train_loss: nan train_acc: 0.755859
# EPOCH 191 STEP 9750 : train_loss: nan train_acc: 0.787109
# EPOCH 192 STEP 9800 : train_loss: nan train_acc: 0.769531
# EPOCH 193 STEP 9850 : train_loss: nan train_acc: 0.728516
# EPOCH 194 STEP 9900 : train_loss: nan train_acc: 0.771484
# EPOCH 195 STEP 9950 : train_loss: nan train_acc: 0.755859
# EPOCH 196 STEP 10000 : train_loss: nan train_acc: 0.751953
# EPOCH 197 STEP 10050 : train_loss: nan train_acc: 0.826172
# EPOCH 198 STEP 10100 : train_loss: nan train_acc: 0.771484
# EPOCH 199 STEP 10150 : train_loss: nan train_acc: 0.775391
# EPOCH 199 STEP 10200 : train_loss: nan train_acc: 0.765625
# EPOCH 200 STEP 10250 : train_loss: nan train_acc: 0.755859
# EPOCH 201 STEP 10300 : train_loss: nan train_acc: 0.753906
# EPOCH 202 STEP 10350 : train_loss: nan train_acc: 0.787109
# EPOCH 203 STEP 10400 : train_loss: nan train_acc: 0.771484
# EPOCH 204 STEP 10450 : train_loss: nan train_acc: 0.771484
# EPOCH 205 STEP 10500 : train_loss: nan train_acc: 0.779297
# EPOCH 206 STEP 10550 : train_loss: nan train_acc: 0.724609
# EPOCH 207 STEP 10600 : train_loss: nan train_acc: 0.738281
# EPOCH 208 STEP 10650 : train_loss: nan train_acc: 0.759766
# EPOCH 209 STEP 10700 : train_loss: nan train_acc: 0.748047
# EPOCH 210 STEP 10750 : train_loss: nan train_acc: 0.750000
# EPOCH 211 STEP 10800 : train_loss: nan train_acc: 0.718750
# EPOCH 212 STEP 10850 : train_loss: nan train_acc: 0.740234
# EPOCH 213 STEP 10900 : train_loss: nan train_acc: 0.720703
# EPOCH 214 STEP 10950 : train_loss: nan train_acc: 0.738281
# EPOCH 215 STEP 11000 : train_loss: nan train_acc: 0.798828
# EPOCH 216 STEP 11050 : train_loss: nan train_acc: 0.751953
# EPOCH 217 STEP 11100 : train_loss: nan train_acc: 0.748047
# EPOCH 218 STEP 11150 : train_loss: nan train_acc: 0.712891
# EPOCH 219 STEP 11200 : train_loss: nan train_acc: 0.773438
# EPOCH 220 STEP 11250 : train_loss: nan train_acc: 0.798828
# EPOCH 221 STEP 11300 : train_loss: nan train_acc: 0.765625
# EPOCH 222 STEP 11350 : train_loss: nan train_acc: 0.791016
# EPOCH 223 STEP 11400 : train_loss: nan train_acc: 0.751953
# EPOCH 224 STEP 11450 : train_loss: nan train_acc: 0.750000
# EPOCH 225 STEP 11500 : train_loss: nan train_acc: 0.761719
# EPOCH 226 STEP 11550 : train_loss: nan train_acc: 0.777344
# EPOCH 227 STEP 11600 : train_loss: nan train_acc: 0.753906
# EPOCH 228 STEP 11650 : train_loss: nan train_acc: 0.783203
# EPOCH 229 STEP 11700 : train_loss: nan train_acc: 0.769531
# EPOCH 230 STEP 11750 : train_loss: nan train_acc: 0.769531
# EPOCH 231 STEP 11800 : train_loss: nan train_acc: 0.744141
# EPOCH 232 STEP 11850 : train_loss: nan train_acc: 0.779297
# EPOCH 233 STEP 11900 : train_loss: nan train_acc: 0.742188
# EPOCH 234 STEP 11950 : train_loss: nan train_acc: 0.736328
# EPOCH 235 STEP 12000 : train_loss: nan train_acc: 0.753906
# EPOCH 236 STEP 12050 : train_loss: nan train_acc: 0.751953
# EPOCH 237 STEP 12100 : train_loss: nan train_acc: 0.734375
# EPOCH 238 STEP 12150 : train_loss: nan train_acc: 0.714844
# EPOCH 239 STEP 12200 : train_loss: nan train_acc: 0.753906
# EPOCH 240 STEP 12250 : train_loss: nan train_acc: 0.738281
# EPOCH 241 STEP 12300 : train_loss: nan train_acc: 0.765625
# EPOCH 242 STEP 12350 : train_loss: nan train_acc: 0.734375
# EPOCH 243 STEP 12400 : train_loss: nan train_acc: 0.777344
# EPOCH 244 STEP 12450 : train_loss: nan train_acc: 0.759766
# EPOCH 245 STEP 12500 : train_loss: nan train_acc: 0.769531
# EPOCH 246 STEP 12550 : train_loss: nan train_acc: 0.773438
# EPOCH 247 STEP 12600 : train_loss: nan train_acc: 0.779297
# EPOCH 248 STEP 12650 : train_loss: nan train_acc: 0.728516
# EPOCH 249 STEP 12700 : train_loss: nan train_acc: 0.765625
# EPOCH 249 STEP 12750 : train_loss: nan train_acc: 0.745536
# EPOCH 250 STEP 12800 : train_loss: nan train_acc: 0.767578
# EPOCH 251 STEP 12850 : train_loss: nan train_acc: 0.781250
# EPOCH 252 STEP 12900 : train_loss: nan train_acc: 0.728516
# EPOCH 253 STEP 12950 : train_loss: nan train_acc: 0.738281
# EPOCH 254 STEP 13000 : train_loss: nan train_acc: 0.802734
# EPOCH 255 STEP 13050 : train_loss: nan train_acc: 0.751953
# EPOCH 256 STEP 13100 : train_loss: nan train_acc: 0.773438
# EPOCH 257 STEP 13150 : train_loss: nan train_acc: 0.763672
# EPOCH 258 STEP 13200 : train_loss: nan train_acc: 0.767578
# EPOCH 259 STEP 13250 : train_loss: nan train_acc: 0.779297
# EPOCH 260 STEP 13300 : train_loss: nan train_acc: 0.769531
# EPOCH 261 STEP 13350 : train_loss: nan train_acc: 0.779297
# EPOCH 262 STEP 13400 : train_loss: nan train_acc: 0.726562
# EPOCH 263 STEP 13450 : train_loss: nan train_acc: 0.763672
# EPOCH 264 STEP 13500 : train_loss: nan train_acc: 0.746094
# EPOCH 265 STEP 13550 : train_loss: nan train_acc: 0.744141
# EPOCH 266 STEP 13600 : train_loss: nan train_acc: 0.779297
# EPOCH 267 STEP 13650 : train_loss: nan train_acc: 0.779297
# EPOCH 268 STEP 13700 : train_loss: nan train_acc: 0.755859
# EPOCH 269 STEP 13750 : train_loss: nan train_acc: 0.773438
# EPOCH 270 STEP 13800 : train_loss: nan train_acc: 0.785156
# EPOCH 271 STEP 13850 : train_loss: nan train_acc: 0.759766
# EPOCH 272 STEP 13900 : train_loss: nan train_acc: 0.759766
# EPOCH 273 STEP 13950 : train_loss: nan train_acc: 0.783203
# EPOCH 274 STEP 14000 : train_loss: nan train_acc: 0.753906
# EPOCH 275 STEP 14050 : train_loss: nan train_acc: 0.732422
# EPOCH 276 STEP 14100 : train_loss: nan train_acc: 0.798828
# EPOCH 277 STEP 14150 : train_loss: nan train_acc: 0.736328
# EPOCH 278 STEP 14200 : train_loss: nan train_acc: 0.746094
# EPOCH 279 STEP 14250 : train_loss: nan train_acc: 0.751953
# EPOCH 280 STEP 14300 : train_loss: nan train_acc: 0.775391
# EPOCH 281 STEP 14350 : train_loss: nan train_acc: 0.750000
# EPOCH 282 STEP 14400 : train_loss: nan train_acc: 0.767578
# EPOCH 283 STEP 14450 : train_loss: nan train_acc: 0.761719
# EPOCH 284 STEP 14500 : train_loss: nan train_acc: 0.804688
# EPOCH 285 STEP 14550 : train_loss: nan train_acc: 0.750000
# EPOCH 286 STEP 14600 : train_loss: nan train_acc: 0.773438
# EPOCH 287 STEP 14650 : train_loss: nan train_acc: 0.783203
# EPOCH 288 STEP 14700 : train_loss: nan train_acc: 0.732422
# EPOCH 289 STEP 14750 : train_loss: nan train_acc: 0.765625
# EPOCH 290 STEP 14800 : train_loss: nan train_acc: 0.751953
# EPOCH 291 STEP 14850 : train_loss: nan train_acc: 0.787109
# EPOCH 292 STEP 14900 : train_loss: nan train_acc: 0.783203
# EPOCH 293 STEP 14950 : train_loss: nan train_acc: 0.796875
# EPOCH 294 STEP 15000 : train_loss: nan train_acc: 0.787109
# EPOCH 295 STEP 15050 : train_loss: nan train_acc: 0.775391
# EPOCH 296 STEP 15100 : train_loss: nan train_acc: 0.761719
# EPOCH 297 STEP 15150 : train_loss: nan train_acc: 0.769531
# EPOCH 298 STEP 15200 : train_loss: nan train_acc: 0.751953
# EPOCH 299 STEP 15250 : train_loss: nan train_acc: 0.769531
# EPOCH 299 STEP 15300 : train_loss: nan train_acc: 0.752232
# EPOCH 300 STEP 15350 : train_loss: nan train_acc: 0.750000
# EPOCH 301 STEP 15400 : train_loss: nan train_acc: 0.738281
# EPOCH 302 STEP 15450 : train_loss: nan train_acc: 0.796875
# EPOCH 303 STEP 15500 : train_loss: nan train_acc: 0.765625
# EPOCH 304 STEP 15550 : train_loss: nan train_acc: 0.734375
# EPOCH 305 STEP 15600 : train_loss: nan train_acc: 0.783203
# EPOCH 306 STEP 15650 : train_loss: nan train_acc: 0.765625
# EPOCH 307 STEP 15700 : train_loss: nan train_acc: 0.763672
# EPOCH 308 STEP 15750 : train_loss: nan train_acc: 0.716797
# EPOCH 309 STEP 15800 : train_loss: nan train_acc: 0.783203
# EPOCH 310 STEP 15850 : train_loss: nan train_acc: 0.767578
# EPOCH 311 STEP 15900 : train_loss: nan train_acc: 0.775391
# EPOCH 312 STEP 15950 : train_loss: nan train_acc: 0.726562
# EPOCH 313 STEP 16000 : train_loss: nan train_acc: 0.771484
# EPOCH 314 STEP 16050 : train_loss: nan train_acc: 0.792969
# EPOCH 315 STEP 16100 : train_loss: nan train_acc: 0.736328
# EPOCH 316 STEP 16150 : train_loss: nan train_acc: 0.757812
# EPOCH 317 STEP 16200 : train_loss: nan train_acc: 0.791016
# EPOCH 318 STEP 16250 : train_loss: nan train_acc: 0.742188
# EPOCH 319 STEP 16300 : train_loss: nan train_acc: 0.740234
# EPOCH 320 STEP 16350 : train_loss: nan train_acc: 0.775391
# EPOCH 321 STEP 16400 : train_loss: nan train_acc: 0.728516
# EPOCH 322 STEP 16450 : train_loss: nan train_acc: 0.761719
# EPOCH 323 STEP 16500 : train_loss: nan train_acc: 0.787109
# EPOCH 324 STEP 16550 : train_loss: nan train_acc: 0.761719
# EPOCH 325 STEP 16600 : train_loss: nan train_acc: 0.792969
# EPOCH 326 STEP 16650 : train_loss: nan train_acc: 0.785156
# EPOCH 327 STEP 16700 : train_loss: nan train_acc: 0.750000
# EPOCH 328 STEP 16750 : train_loss: nan train_acc: 0.710938
# EPOCH 329 STEP 16800 : train_loss: nan train_acc: 0.751953
# EPOCH 330 STEP 16850 : train_loss: nan train_acc: 0.785156
# EPOCH 331 STEP 16900 : train_loss: nan train_acc: 0.757812
# EPOCH 332 STEP 16950 : train_loss: nan train_acc: 0.761719
# EPOCH 333 STEP 17000 : train_loss: nan train_acc: 0.773438
# EPOCH 334 STEP 17050 : train_loss: nan train_acc: 0.761719
# EPOCH 335 STEP 17100 : train_loss: nan train_acc: 0.763672
# EPOCH 336 STEP 17150 : train_loss: nan train_acc: 0.757812
# EPOCH 337 STEP 17200 : train_loss: nan train_acc: 0.783203
# EPOCH 338 STEP 17250 : train_loss: nan train_acc: 0.728516
# EPOCH 339 STEP 17300 : train_loss: nan train_acc: 0.742188
# EPOCH 340 STEP 17350 : train_loss: nan train_acc: 0.753906
# EPOCH 341 STEP 17400 : train_loss: nan train_acc: 0.751953
# EPOCH 342 STEP 17450 : train_loss: nan train_acc: 0.775391
# EPOCH 343 STEP 17500 : train_loss: nan train_acc: 0.746094
# EPOCH 344 STEP 17550 : train_loss: nan train_acc: 0.763672
# EPOCH 345 STEP 17600 : train_loss: nan train_acc: 0.718750
# EPOCH 346 STEP 17650 : train_loss: nan train_acc: 0.773438
# EPOCH 347 STEP 17700 : train_loss: nan train_acc: 0.750000
# EPOCH 348 STEP 17750 : train_loss: nan train_acc: 0.804688
# EPOCH 349 STEP 17800 : train_loss: nan train_acc: 0.722656
# EPOCH 349 STEP 17850 : train_loss: nan train_acc: 0.758929
# EPOCH 350 STEP 17900 : train_loss: nan train_acc: 0.777344
# EPOCH 351 STEP 17950 : train_loss: nan train_acc: 0.746094
# EPOCH 352 STEP 18000 : train_loss: nan train_acc: 0.765625
# EPOCH 353 STEP 18050 : train_loss: nan train_acc: 0.792969
# EPOCH 354 STEP 18100 : train_loss: nan train_acc: 0.763672
# EPOCH 355 STEP 18150 : train_loss: nan train_acc: 0.755859
# EPOCH 356 STEP 18200 : train_loss: nan train_acc: 0.744141
# EPOCH 357 STEP 18250 : train_loss: nan train_acc: 0.759766
# EPOCH 358 STEP 18300 : train_loss: nan train_acc: 0.726562
# EPOCH 359 STEP 18350 : train_loss: nan train_acc: 0.769531
# EPOCH 360 STEP 18400 : train_loss: nan train_acc: 0.701172
# EPOCH 361 STEP 18450 : train_loss: nan train_acc: 0.769531
# EPOCH 362 STEP 18500 : train_loss: nan train_acc: 0.765625
# EPOCH 363 STEP 18550 : train_loss: nan train_acc: 0.755859
# EPOCH 364 STEP 18600 : train_loss: nan train_acc: 0.751953
# EPOCH 365 STEP 18650 : train_loss: nan train_acc: 0.742188
# EPOCH 366 STEP 18700 : train_loss: nan train_acc: 0.757812
# EPOCH 367 STEP 18750 : train_loss: nan train_acc: 0.751953
# EPOCH 368 STEP 18800 : train_loss: nan train_acc: 0.779297
# EPOCH 369 STEP 18850 : train_loss: nan train_acc: 0.751953
# EPOCH 370 STEP 18900 : train_loss: nan train_acc: 0.755859
# EPOCH 371 STEP 18950 : train_loss: nan train_acc: 0.781250
# EPOCH 372 STEP 19000 : train_loss: nan train_acc: 0.755859
# EPOCH 373 STEP 19050 : train_loss: nan train_acc: 0.750000
# EPOCH 374 STEP 19100 : train_loss: nan train_acc: 0.755859
# EPOCH 375 STEP 19150 : train_loss: nan train_acc: 0.781250
# EPOCH 376 STEP 19200 : train_loss: nan train_acc: 0.781250
# EPOCH 377 STEP 19250 : train_loss: nan train_acc: 0.763672
# EPOCH 378 STEP 19300 : train_loss: nan train_acc: 0.750000
# EPOCH 379 STEP 19350 : train_loss: nan train_acc: 0.751953
# EPOCH 380 STEP 19400 : train_loss: nan train_acc: 0.759766
# EPOCH 381 STEP 19450 : train_loss: nan train_acc: 0.738281
# EPOCH 382 STEP 19500 : train_loss: nan train_acc: 0.742188
# EPOCH 383 STEP 19550 : train_loss: nan train_acc: 0.755859
# EPOCH 384 STEP 19600 : train_loss: nan train_acc: 0.761719
# EPOCH 385 STEP 19650 : train_loss: nan train_acc: 0.769531
# EPOCH 386 STEP 19700 : train_loss: nan train_acc: 0.771484
# EPOCH 387 STEP 19750 : train_loss: nan train_acc: 0.748047
# EPOCH 388 STEP 19800 : train_loss: nan train_acc: 0.746094
# EPOCH 389 STEP 19850 : train_loss: nan train_acc: 0.759766
# EPOCH 390 STEP 19900 : train_loss: nan train_acc: 0.796875
# EPOCH 391 STEP 19950 : train_loss: nan train_acc: 0.755859
# EPOCH 392 STEP 20000 : train_loss: nan train_acc: 0.759766
# EPOCH 393 STEP 20050 : train_loss: nan train_acc: 0.750000
# EPOCH 394 STEP 20100 : train_loss: nan train_acc: 0.757812
# EPOCH 395 STEP 20150 : train_loss: nan train_acc: 0.787109
# EPOCH 396 STEP 20200 : train_loss: nan train_acc: 0.734375
# EPOCH 397 STEP 20250 : train_loss: nan train_acc: 0.757812
# EPOCH 398 STEP 20300 : train_loss: nan train_acc: 0.806641
# EPOCH 399 STEP 20350 : train_loss: nan train_acc: 0.750000
# EPOCH 399 STEP 20400 : train_loss: nan train_acc: 0.756696
# EPOCH 400 STEP 20450 : train_loss: nan train_acc: 0.755859
# EPOCH 401 STEP 20500 : train_loss: nan train_acc: 0.777344
# EPOCH 402 STEP 20550 : train_loss: nan train_acc: 0.738281
# EPOCH 403 STEP 20600 : train_loss: nan train_acc: 0.750000
# EPOCH 404 STEP 20650 : train_loss: nan train_acc: 0.765625
# EPOCH 405 STEP 20700 : train_loss: nan train_acc: 0.742188
# EPOCH 406 STEP 20750 : train_loss: nan train_acc: 0.742188
# EPOCH 407 STEP 20800 : train_loss: nan train_acc: 0.775391
# EPOCH 408 STEP 20850 : train_loss: nan train_acc: 0.759766
# EPOCH 409 STEP 20900 : train_loss: nan train_acc: 0.750000
# EPOCH 410 STEP 20950 : train_loss: nan train_acc: 0.751953
# EPOCH 411 STEP 21000 : train_loss: nan train_acc: 0.753906
# EPOCH 412 STEP 21050 : train_loss: nan train_acc: 0.775391
# EPOCH 413 STEP 21100 : train_loss: nan train_acc: 0.750000
# EPOCH 414 STEP 21150 : train_loss: nan train_acc: 0.722656
# EPOCH 415 STEP 21200 : train_loss: nan train_acc: 0.724609
# EPOCH 416 STEP 21250 : train_loss: nan train_acc: 0.777344
# EPOCH 417 STEP 21300 : train_loss: nan train_acc: 0.718750
# EPOCH 418 STEP 21350 : train_loss: nan train_acc: 0.740234
# EPOCH 419 STEP 21400 : train_loss: nan train_acc: 0.769531
# EPOCH 420 STEP 21450 : train_loss: nan train_acc: 0.765625
# EPOCH 421 STEP 21500 : train_loss: nan train_acc: 0.769531
# EPOCH 422 STEP 21550 : train_loss: nan train_acc: 0.748047
# EPOCH 423 STEP 21600 : train_loss: nan train_acc: 0.781250
# EPOCH 424 STEP 21650 : train_loss: nan train_acc: 0.765625
# EPOCH 425 STEP 21700 : train_loss: nan train_acc: 0.783203
# EPOCH 426 STEP 21750 : train_loss: nan train_acc: 0.769531
# EPOCH 427 STEP 21800 : train_loss: nan train_acc: 0.789062
# EPOCH 428 STEP 21850 : train_loss: nan train_acc: 0.789062
# EPOCH 429 STEP 21900 : train_loss: nan train_acc: 0.755859
# EPOCH 430 STEP 21950 : train_loss: nan train_acc: 0.746094
# EPOCH 431 STEP 22000 : train_loss: nan train_acc: 0.800781
# EPOCH 432 STEP 22050 : train_loss: nan train_acc: 0.759766
# EPOCH 433 STEP 22100 : train_loss: nan train_acc: 0.804688
# EPOCH 434 STEP 22150 : train_loss: nan train_acc: 0.748047
# EPOCH 435 STEP 22200 : train_loss: nan train_acc: 0.777344
# EPOCH 436 STEP 22250 : train_loss: nan train_acc: 0.751953
# EPOCH 437 STEP 22300 : train_loss: nan train_acc: 0.779297
# EPOCH 438 STEP 22350 : train_loss: nan train_acc: 0.755859
# EPOCH 439 STEP 22400 : train_loss: nan train_acc: 0.746094
# EPOCH 440 STEP 22450 : train_loss: nan train_acc: 0.742188
# EPOCH 441 STEP 22500 : train_loss: nan train_acc: 0.771484
# EPOCH 442 STEP 22550 : train_loss: nan train_acc: 0.751953
# EPOCH 443 STEP 22600 : train_loss: nan train_acc: 0.761719
# EPOCH 444 STEP 22650 : train_loss: nan train_acc: 0.755859
# EPOCH 445 STEP 22700 : train_loss: nan train_acc: 0.738281
# EPOCH 446 STEP 22750 : train_loss: nan train_acc: 0.757812
# EPOCH 447 STEP 22800 : train_loss: nan train_acc: 0.746094
# EPOCH 448 STEP 22850 : train_loss: nan train_acc: 0.773438
# EPOCH 449 STEP 22900 : train_loss: nan train_acc: 0.730469
# EPOCH 449 STEP 22950 : train_loss: nan train_acc: 0.772321
# EPOCH 450 STEP 23000 : train_loss: nan train_acc: 0.753906
# EPOCH 451 STEP 23050 : train_loss: nan train_acc: 0.761719
# EPOCH 452 STEP 23100 : train_loss: nan train_acc: 0.738281
# EPOCH 453 STEP 23150 : train_loss: nan train_acc: 0.724609
# EPOCH 454 STEP 23200 : train_loss: nan train_acc: 0.775391
# EPOCH 455 STEP 23250 : train_loss: nan train_acc: 0.777344
# EPOCH 456 STEP 23300 : train_loss: nan train_acc: 0.789062
# EPOCH 457 STEP 23350 : train_loss: nan train_acc: 0.773438
# EPOCH 458 STEP 23400 : train_loss: nan train_acc: 0.744141
# EPOCH 459 STEP 23450 : train_loss: nan train_acc: 0.751953
# EPOCH 460 STEP 23500 : train_loss: nan train_acc: 0.781250
# EPOCH 461 STEP 23550 : train_loss: nan train_acc: 0.736328
# EPOCH 462 STEP 23600 : train_loss: nan train_acc: 0.742188
# EPOCH 463 STEP 23650 : train_loss: nan train_acc: 0.734375
# EPOCH 464 STEP 23700 : train_loss: nan train_acc: 0.753906
# EPOCH 465 STEP 23750 : train_loss: nan train_acc: 0.763672
# EPOCH 466 STEP 23800 : train_loss: nan train_acc: 0.779297
# EPOCH 467 STEP 23850 : train_loss: nan train_acc: 0.763672
# EPOCH 468 STEP 23900 : train_loss: nan train_acc: 0.791016
# EPOCH 469 STEP 23950 : train_loss: nan train_acc: 0.796875
# EPOCH 470 STEP 24000 : train_loss: nan train_acc: 0.750000
# EPOCH 471 STEP 24050 : train_loss: nan train_acc: 0.744141
# EPOCH 472 STEP 24100 : train_loss: nan train_acc: 0.755859
# EPOCH 473 STEP 24150 : train_loss: nan train_acc: 0.767578
# EPOCH 474 STEP 24200 : train_loss: nan train_acc: 0.734375
# EPOCH 475 STEP 24250 : train_loss: nan train_acc: 0.718750
# EPOCH 476 STEP 24300 : train_loss: nan train_acc: 0.779297
# EPOCH 477 STEP 24350 : train_loss: nan train_acc: 0.775391
# EPOCH 478 STEP 24400 : train_loss: nan train_acc: 0.740234
# EPOCH 479 STEP 24450 : train_loss: nan train_acc: 0.775391
# EPOCH 480 STEP 24500 : train_loss: nan train_acc: 0.755859
# EPOCH 481 STEP 24550 : train_loss: nan train_acc: 0.769531
# EPOCH 482 STEP 24600 : train_loss: nan train_acc: 0.773438
# EPOCH 483 STEP 24650 : train_loss: nan train_acc: 0.750000
# EPOCH 484 STEP 24700 : train_loss: nan train_acc: 0.734375
# EPOCH 485 STEP 24750 : train_loss: nan train_acc: 0.732422
# EPOCH 486 STEP 24800 : train_loss: nan train_acc: 0.767578
# EPOCH 487 STEP 24850 : train_loss: nan train_acc: 0.775391
# EPOCH 488 STEP 24900 : train_loss: nan train_acc: 0.753906
# EPOCH 489 STEP 24950 : train_loss: nan train_acc: 0.751953
# EPOCH 490 STEP 25000 : train_loss: nan train_acc: 0.751953
# EPOCH 491 STEP 25050 : train_loss: nan train_acc: 0.771484
# EPOCH 492 STEP 25100 : train_loss: nan train_acc: 0.720703
# EPOCH 493 STEP 25150 : train_loss: nan train_acc: 0.736328
# EPOCH 494 STEP 25200 : train_loss: nan train_acc: 0.773438
# EPOCH 495 STEP 25250 : train_loss: nan train_acc: 0.783203
# EPOCH 496 STEP 25300 : train_loss: nan train_acc: 0.738281
# EPOCH 497 STEP 25350 : train_loss: nan train_acc: 0.728516
# EPOCH 498 STEP 25400 : train_loss: nan train_acc: 0.736328
# EPOCH 499 STEP 25450 : train_loss: nan train_acc: 0.748047
# EPOCH 499 STEP 25500 : train_loss: nan train_acc: 0.729911

# %% [markdown]
# # Домашка
# 1. Пофиксить лосс nan (поиграться с фичами в CustomDataset)
# 2. Добавить в run_train проверку на valid
